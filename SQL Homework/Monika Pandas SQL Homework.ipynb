# %%
# Pandas
import pandas as pd

#%matplotlib inline
# %matplotlib notebook

import matplotlib.pyplot as plt

# SQL Alchemy
from sqlalchemy import create_engine

# %%
#import Postgres Database
engine = create_engine('postgresql://postgres:Spanky007@localhost:5432/Employee_db')
connect = engine.connect()

#run a test import from table and shows head
test = pd.read_sql_query('SELECT * FROM dept', connect)
test.head()
# Out:
#   dept_no        dept_name
# 0    d001        Marketing
# 1    d002          Finance
# 2    d003  Human Resources
# 3    d004       Production
# 4    d005      Development

# %%
#Create a bar chart of average salary by title.

avg_sal_title_df = pd.read_sql_query('SELECT * FROM avg_salary_by_title', connect)
avg_sal_title_df
# Out:
#                 title    avg_salary
# 0  Assistant Engineer  48493.204786
# 1            Engineer  48539.781423
# 2             Manager  51531.041667
# 3     Senior Engineer  48506.751806
# 4        Senior Staff  58503.286614
# 5               Staff  58465.271904
# 6    Technique Leader  48580.505772

# %%
#Create a bar chart of average salary by title using pandas.

avg_sal_title_df.plot(kind='bar', x='title', y='avg_salary', title='Average Salary by Title')

# Set textual properties
plt.title('Average Salary by Title')
plt.ylabel("AVG Salary")
plt.xlabel("Job Title")

# Show plot
plt.savefig("avg_salary_by_title_bar_chart.png", index=False, header=True)

#plt.show(10)
#plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
